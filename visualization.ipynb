# %%
from utilities.loaders import load_meta_data
from utilities.visualizers import ModelResults, view_all_splits_results

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
softmax_history = load_meta_data("./results/softmax_history.json")

# %%
epochs = list(range(0, len(softmax_history["auc"])))

# %%
softmax_results = ModelResults(softmax_history, epochs)

# %%
view_all_splits_results(softmax_history)
# Out:
#          auc  categorical_accuracy  categorical_crossentropy  f1_score  \
# 0   0.453066              0.270633              4.876583e+27  0.334091
# 1   0.555410              0.421016              4.508539e+27  0.480519
# 2   0.646002              0.547653              5.060607e+27  0.568373
# 3   0.655063              0.552345              4.508541e+27  0.571024
# 4   0.669364              0.568619              5.336640e+27  0.580541
# 5   0.683706              0.586411              4.232507e+27  0.590744
# 6   0.704929              0.613348              4.324518e+27  0.605399
# 7   0.500253              0.335377              4.508541e+27  0.404257
# 8   0.730663              0.643703              5.336640e+27  0.620826
# 9   0.692826              0.593903              4.600551e+27  0.595928
# 10  0.666010              0.558190              5.060607e+27  0.581544
# 11  0.651650              0.538368              4.232507e+27  0.567573
# ...

# %%
softmax_results.export_results(dataset_id="gendered audio recordings", metrics_to_use=["auc", "val_auc", "recall_1", "val_recall_1", "precision_1", "val_precision_1", "categorical_accuracy", "val_categorical_accuracy", "loss", "val_loss", "categorical_crossentropy", "val_categorical_crossentropy", "f1_score", "val_f1_score"])
# Out:
# auc
# val_auc
# ...
